# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df = df[["Sleep Duration", "Stress Level"]]

# %%
df
# Out:
#      Sleep Duration  Stress Level
# 0               6.1             6
# 1               6.2             8
# 2               6.2             8
# 3               5.9             8
# 4               5.9             8
# ..              ...           ...
# 369             8.1             3
# 370             8.0             3
# 371             8.1             3
# 372             8.1             3
# 373             8.1             3
#
# [374 rows x 2 columns]

# %%
X = df.drop("Stress Level", axis=1)

# %%
y = df["Stress Level"]

# %%
X
# Out:
#      Sleep Duration
# 0               6.1
# 1               6.2
# 2               6.2
# 3               5.9
# 4               5.9
# ..              ...
# 369             8.1
# 370             8.0
# 371             8.1
# 372             8.1
# 373             8.1
#
# [374 rows x 1 columns]

# %%
y
# Out:
# 0      6
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 369    3
# 370    3
# 371    3
# 372    3
# 373    3
# Name: Stress Level, Length: 374, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
y_pred
# Out:
# array([7.2518604 , 7.07098066, 7.07098066, 7.61361987, 7.61361987,
#        7.61361987, 6.89010092, 4.17690485, 4.17690485, 4.17690485,
#        7.2518604 , 4.17690485, 7.2518604 , 7.43274014, 7.43274014,
#        7.43274014, 6.52834145, 7.43274014, 6.52834145, 4.53866433,
#        4.35778459, 4.35778459, 4.35778459, 4.35778459, 4.17690485,
#        3.99602511, 4.17690485, 3.99602511, 3.99602511, 3.99602511,
#        6.70922118, 6.70922118, 3.99602511, 7.2518604 , 4.35778459,
#        7.2518604 , 7.2518604 , 4.53866433, 4.53866433, 4.53866433,
#        4.35778459, 4.35778459, 4.35778459, 4.17690485, 4.35778459,
#        4.17690485, 4.35778459, 4.17690485, 4.35778459, 4.35778459,
#        4.71954407, 4.71954407, 7.43274014, 4.53866433, 7.43274014,
#        7.43274014, 4.35778459, 7.43274014, 7.43274014, 4.35778459,
#        7.43274014, 7.43274014, 7.07098066, 7.07098066, 7.07098066,
#        7.07098066, 5.26218328, 7.43274014, 7.07098066, 7.07098066,
#        7.2518604 , 7.2518604 , 7.2518604 , 7.2518604 , 7.43274014,
#        7.43274014, 7.43274014, 7.43274014, 7.43274014, 7.43274014,
#        7.79449961, 7.79449961, 6.16658197, 6.16658197, 4.71954407,
#        5.26218328, 5.26218328, 5.26218328, 5.08130354, 5.08130354,
#        5.08130354, 5.08130354, 4.71954407, 4.9004238 , 5.26218328,
#        5.44306302, 5.26218328, 5.44306302, 5.44306302, 5.44306302,
#        5.26218328, 5.26218328, 5.26218328, 6.34746171, 5.26218328,
#        6.34746171, 7.2518604 , 4.17690485, 4.17690485, 4.9004238 ,
#        5.26218328, 4.9004238 , 5.26218328, 4.9004238 , 5.26218328,
#        5.26218328, 5.26218328, 5.26218328, 5.26218328, 5.26218328,
#        5.26218328, 5.26218328, 5.26218328, 5.26218328, 5.26218328,
#        4.71954407, 5.08130354, 5.44306302, 5.08130354, 5.08130354,
#        5.44306302, 5.08130354, 5.08130354, 5.44306302, 5.08130354,
#        5.08130354, 5.44306302, 5.44306302, 5.44306302, 5.44306302,
#        5.44306302, 5.44306302, 5.44306302, 5.44306302, 5.44306302,
#        4.9004238 , 5.26218328, 6.52834145, 5.80482249, 3.81514538,
#        3.81514538, 5.26218328, 5.26218328, 5.26218328, 5.26218328,
#        5.26218328, 5.26218328, 5.26218328, 5.26218328, 5.26218328,
#        5.26218328, 5.26218328, 5.26218328, 3.99602511, 3.99602511,
#        4.53866433, 5.08130354, 5.44306302, 5.44306302, 4.35778459,
#        4.35778459, 4.35778459, 4.35778459, 4.35778459, 4.53866433,
#        4.53866433, 4.53866433, 6.52834145, 4.17690485, 4.17690485,
#        4.17690485, 4.17690485, 4.17690485, 4.17690485, 5.98570223,
#        5.98570223, 6.16658197, 6.89010092, 6.16658197, 6.52834145,
#        6.16658197, 6.70922118, 6.52834145, 6.52834145, 6.52834145,
#        6.52834145, 6.52834145, 6.52834145, 6.52834145, 6.52834145,
#        6.52834145, 4.17690485, 4.17690485, 5.80482249, 4.53866433,
#        4.35778459, 4.35778459, 4.35778459, 4.35778459, 4.17690485,
#        4.35778459, 4.17690485, 4.17690485, 4.17690485, 4.17690485,
#        4.17690485, 4.17690485, 4.17690485, 4.17690485, 6.52834145,
#        6.34746171, 6.70922118, 6.89010092, 6.70922118, 6.34746171,
#        6.89010092, 6.34746171, 6.89010092, 6.34746171, 6.89010092,
#        6.34746171, 6.89010092, 6.34746171, 6.89010092, 6.34746171,
#        6.89010092, 6.70922118, 6.52834145, 6.89010092, 6.70922118,
#        6.52834145, 6.89010092, 6.70922118, 6.52834145, 6.89010092,
#        6.52834145, 6.89010092, 5.98570223, 6.70922118, 6.52834145,
#        5.98570223, 5.98570223, 6.52834145, 6.52834145, 6.52834145,
#        6.52834145, 6.34746171, 6.34746171, 6.34746171, 6.34746171,
#        6.34746171, 6.34746171, 6.34746171, 5.80482249, 5.08130354,
#        7.61361987, 5.08130354, 7.07098066, 7.43274014, 7.2518604 ,
#        7.2518604 , 7.2518604 , 7.2518604 , 7.07098066, 7.07098066,
#        7.07098066, 3.63426564, 3.63426564, 7.2518604 , 3.27250616,
#        7.43274014, 7.2518604 , 7.43274014, 7.43274014, 7.43274014,
#        7.43274014, 7.43274014, 7.43274014, 7.43274014, 7.2518604 ,
#        7.43274014, 7.2518604 , 7.2518604 , 7.43274014, 7.2518604 ,
#        7.43274014, 7.2518604 , 7.2518604 , 2.91074669, 2.91074669,
#        2.91074669, 2.91074669, 5.44306302, 7.43274014, 7.2518604 ,
#        7.2518604 , 6.52834145, 6.52834145, 6.34746171, 6.34746171,
#        6.34746171, 6.34746171, 3.09162642, 3.09162642, 3.09162642,
#        3.27250616, 2.91074669, 2.91074669, 3.09162642, 3.09162642,
#        2.91074669, 3.09162642, 3.09162642, 2.91074669, 3.27250616,
#        2.91074669, 3.27250616, 2.91074669, 3.27250616, 2.91074669,
#        2.91074669, 3.09162642, 3.09162642, 3.09162642, 3.09162642,
#        3.09162642, 3.09162642, 3.09162642, 2.91074669, 3.63426564,
#        3.63426564, 3.4533859 , 3.4533859 , 3.63426564, 3.4533859 ,
#        3.4533859 , 3.4533859 , 3.4533859 , 3.4533859 , 3.63426564,
#        3.63426564, 3.63426564, 3.81514538, 3.81514538, 3.81514538,
#        3.81514538, 3.81514538, 3.81514538, 3.81514538, 3.63426564,
#        3.4533859 , 3.4533859 , 3.4533859 , 3.4533859 , 3.81514538,
#        3.81514538, 3.63426564, 3.81514538, 3.63426564, 3.63426564,
#        3.81514538, 3.63426564, 3.63426564, 3.63426564])

# %%
plt.scatter(X, y, color='blue', label="Actual")
plt.plot(X, y_pred, color='red', label="Prediction")
plt.legend()
plt.show()

# %%
m = model.coef_[0]  # Slope
b = model.intercept_  # Intercept
f"Formula: y = {m:.2f}x+ {b:.2f}"
# Out:
# 'Formula: y = -1.81x+ 18.29'

# %%
sleep_duration = np.array([[7.5]])
predicted_stress = model.predict(sleep_duration)
print(f"Predicted stress for Sleep Duration = 7.5: {predicted_stress[0]:.2f}")
# Out:
# Predicted stress for Sleep Duration = 7.5: 4.72
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
